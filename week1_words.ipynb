# %%
import re
from collections import Counter

# 定義法文字詞的清單
french_words = {"d’ecroissance"}

# 判斷是否是法文字
def is_french(word):
    return word in french_words

# 將縮寫拆分為兩個單字
def split_contractions(text):
    contractions = {
        "it's": "it is",
        "don't": "do not",
        "can't": "cannot",
        "I've": "I have",
        "you're": "you are",
        "he's": "he is",
        "she's": "she is",
        "we're": "we are",
        "they're": "they are",
        "isn't": "is not",
        "wasn't": "was not",
    }
    
    # 替換縮寫為完整形式
    for contraction, full_form in contractions.items():
        text = re.sub(r"\b" + contraction + r"\b", full_form, text)
    
    return text

# 主要函數，進行處理並建立字典
def analyze_text(file_content):
    text = file_content.lower()  # 將所有文本轉為小寫
    text = split_contractions(text)  # 拆分縮寫
    
    # 使用正則表達式進行自定義分詞，避免拆分 d'ecroissance
    words = re.findall(r"d'ecroissance|\b[a-zA-Z'’]+\b", text)

    word_counter = Counter(words)  # 計算頻率
    
    result = {}
    
    for word in word_counter.keys():
        result[word] = {
            "frequency": word_counter[word],  # 單字頻率
            "POS": "english" if word.isalpha() else "unknown",  # 詞性 (假設非法文字為英文)
            "length": len(word),  # 單字長度
            "lowercase": word,  # 小寫形式
            "starts_with_a_to_z": 'a' <= word[0] <= 'z',  # 是否以 a 到 z 開頭
            "type": "french" if is_french(word) else "english"  # 判斷是否是法文字
        }
        """
        # 確保 d'ecroissance 被標記為法文字
        if word == "d'ecroissance":
            result[word] = {
                "frequency": word_counter[word],  # 單字頻率
                "POS": "french",  # 直接設置詞性為法語
                "length": len(word),  # 單字長度
                "lowercase": word,  # 小寫形式
                "starts_with_a_to_z": 'a' <= word[0] <= 'z',  # 是否以 a 到 z 開頭
                "type": "french"  # 判斷為法文字
            }
        else:
            # 對於其他單字，使用字母的對應規則來推斷詞性
            result[word] = {
                "frequency": word_counter[word],  # 單字頻率
                "POS": "english" if word.isalpha() else "unknown",  # 詞性 (假設非法文字為英文)
                "length": len(word),  # 單字長度
                "lowercase": word,  # 小寫形式
                "starts_with_a_to_z": 'a' <= word[0] <= 'z',  # 是否以 a 到 z 開頭
                "type": "french" if is_french(word) else "english"  # 判斷是否是法文字
            }
        """
    
    return result

# 讀取文本檔案
file_path = 't1.txt'
with open(file_path, 'r', encoding='utf-8') as file:
    text = file.read()

# 使用 analyze_text 函數來分析文本
result = analyze_text(text)

# 顯示結果
for word, info in result.items():
    print(f"Word: {word}")
    for key, value in info.items():
        print(f"  {key}: {value}")
    print()
# Out:
# Word: the
#   frequency: 18
#   POS: english
#   length: 3
#   lowercase: the
#   starts_with_a_to_z: True
#   type: english
#
# Word: idea
#   frequency: 2
#   POS: english
#   length: 4
#   lowercase: idea
#   starts_with_a_to_z: True
#   type: english
#
# Word: of
#   frequency: 15
#   POS: english
#   length: 2
#   lowercase: of
#   starts_with_a_to_z: True
#   type: english
#
# Word: d’ecroissance
#   frequency: 11
#   POS: unknown
#   length: 13
#   lowercase: d’ecroissance
#   starts_with_a_to_z: True
#   type: french
#
# Word: emerged
#   frequency: 1
#   POS: english
#   length: 7
#   lowercase: emerged
#   starts_with_a_to_z: True
#   type: english
#
# Word: in
#   frequency: 12
#   POS: english
#   length: 2
#   lowercase: in
#   starts_with_a_to_z: True
#   type: english
#
# Word: france
#   frequency: 1
#   POS: english
#   length: 6
#   lowercase: france
#   starts_with_a_to_z: True
#   type: english
#
# Word: mid
#   frequency: 1
#   POS: english
#   length: 3
#   lowercase: mid
#   starts_with_a_to_z: True
#   type: english
#
# Word: as
#   frequency: 10
#   POS: english
#   length: 2
#   lowercase: as
#   starts_with_a_to_z: True
#   type: english
#
# Word: a
#   frequency: 12
#   POS: english
#   length: 1
#   lowercase: a
#   starts_with_a_to_z: True
#   type: english
#
# Word: direct
#   frequency: 1
#   POS: english
#   length: 6
#   lowercase: direct
#   starts_with_a_to_z: True
#   type: english
#
# Word: reaction
#   frequency: 1
#   POS: english
#   length: 8
#   lowercase: reaction
#   starts_with_a_to_z: True
#   type: english
#
# Word: to
#   frequency: 13
#   POS: english
#   length: 2
#   lowercase: to
#   starts_with_a_to_z: True
#   type: english
#
# Word: limits
#   frequency: 1
#   POS: english
#   length: 6
#   lowercase: limits
#   starts_with_a_to_z: True
#   type: english
#
# Word: growth
#   frequency: 2
#   POS: english
#   length: 6
#   lowercase: growth
#   starts_with_a_to_z: True
#   type: english
#
# Word: according
#   frequency: 2
#   POS: english
#   length: 9
#   lowercase: according
#   starts_with_a_to_z: True
#   type: english
#
# Word: muraca
#   frequency: 1
#   POS: english
#   length: 6
#   lowercase: muraca
#   starts_with_a_to_z: True
#   type: english
#
# Word: was
#   frequency: 1
#   POS: english
#   length: 3
#   lowercase: was
#   starts_with_a_to_z: True
#   type: english
#
# Word: first
#   frequency: 1
#   POS: english
#   length: 5
#   lowercase: first
#   starts_with_a_to_z: True
#   type: english
#
# Word: used
#   frequency: 1
#   POS: english
#   length: 4
#   lowercase: used
#   starts_with_a_to_z: True
#   type: english
#
# Word: term
#   frequency: 1
#   POS: english
#   length: 4
#   lowercase: term
#   starts_with_a_to_z: True
#   type: english
#
# Word: by
#   frequency: 2
#   POS: english
#   length: 2
#   lowercase: by
#   starts_with_a_to_z: True
#   type: english
#
# Word: amar
#   frequency: 1
#   POS: english
#   length: 4
#   lowercase: amar
#   starts_with_a_to_z: True
#   type: english
#
# Word: rather
#   frequency: 3
#   POS: english
#   length: 6
#   lowercase: rather
#   starts_with_a_to_z: True
#   type: english
#
# Word: loose
#   frequency: 1
#   POS: english
#   length: 5
#   lowercase: loose
#   starts_with_a_to_z: True
#   type: english
#
# Word: way
#   frequency: 1
#   POS: english
#   length: 3
#   lowercase: way
#   starts_with_a_to_z: True
#   type: english
#
# Word: critically
#   frequency: 1
#   POS: english
#   length: 10
#   lowercase: critically
#   starts_with_a_to_z: True
#   type: english
#
# Word: reflect
#   frequency: 1
#   POS: english
#   length: 7
#   lowercase: reflect
#   starts_with_a_to_z: True
#   type: english
#
# Word: upon
#   frequency: 1
#   POS: english
#   length: 4
#   lowercase: upon
#   starts_with_a_to_z: True
#   type: english
#
# Word: western
#   frequency: 2
#   POS: english
#   length: 7
#   lowercase: western
#   starts_with_a_to_z: True
#   type: english
#
# Word: model
#   frequency: 2
#   POS: english
#   length: 5
#   lowercase: model
#   starts_with_a_to_z: True
#   type: english
#
# Word: economic
#   frequency: 6
#   POS: english
#   length: 8
#   lowercase: economic
#   starts_with_a_to_z: True
#   type: english
#
# Word: development
#   frequency: 3
#   POS: english
#   length: 11
#   lowercase: development
#   starts_with_a_to_z: True
#   type: english
#
# Word: before
#   frequency: 1
#   POS: english
#   length: 6
#   lowercase: before
#   starts_with_a_to_z: True
#   type: english
#
# Word: french
#   frequency: 4
#   POS: english
#   length: 6
#   lowercase: french
#   starts_with_a_to_z: True
#   type: english
#
# Word: translations
#   frequency: 1
#   POS: english
#   length: 12
#   lowercase: translations
#   starts_with_a_to_z: True
#   type: english
#
# Word: some
#   frequency: 1
#   POS: english
#   length: 4
#   lowercase: some
#   starts_with_a_to_z: True
#   type: english
#
# Word: works
#   frequency: 1
#   POS: english
#   length: 5
#   lowercase: works
#   starts_with_a_to_z: True
#   type: english
#
# Word: georgescu
#   frequency: 3
#   POS: english
#   length: 9
#   lowercase: georgescu
#   starts_with_a_to_z: True
#   type: english
#
# Word: roegen
#   frequency: 1
#   POS: english
#   length: 6
#   lowercase: roegen
#   starts_with_a_to_z: True
#   type: english
#
# Word: rocgen
#   frequency: 1
#   POS: english
#   length: 6
#   lowercase: rocgen
#   starts_with_a_to_z: True
#   type: english
#
# Word: populaeized
#   frequency: 1
#   POS: english
#   length: 11
#   lowercase: populaeized
#   starts_with_a_to_z: True
#   type: english
#
# Word: an
#   frequency: 1
#   POS: english
#   length: 2
#   lowercase: an
#   starts_with_a_to_z: True
#   type: english
#
# Word: alternative
#   frequency: 2
#   POS: english
#   length: 11
#   lowercase: alternative
#   starts_with_a_to_z: True
#   type: english
#
# Word: already
#   frequency: 1
#   POS: english
#   length: 7
#   lowercase: already
#   starts_with_a_to_z: True
#   type: english
#
# Word: established
#   frequency: 2
#   POS: english
#   length: 11
#   lowercase: established
#   starts_with_a_to_z: True
#   type: english
#
# Word: z’egisme
#   frequency: 1
#   POS: unknown
#   length: 8
#   lowercase: z’egisme
#   starts_with_a_to_z: True
#   type: english
#
# Word: i
#   frequency: 2
#   POS: english
#   length: 1
#   lowercase: i
#   starts_with_a_to_z: True
#   type: english
#
# Word: e
#   frequency: 3
#   POS: english
#   length: 1
#   lowercase: e
#   starts_with_a_to_z: True
#   type: english
#
# Word: zero
#   frequency: 1
#   POS: english
#   length: 4
#   lowercase: zero
#   starts_with_a_to_z: True
#   type: english
#
# Word: particular
#   frequency: 3
#   POS: english
#   length: 10
#   lowercase: particular
#   starts_with_a_to_z: True
#   type: english
#
# Word: roegon
#   frequency: 1
#   POS: english
#   length: 6
#   lowercase: roegon
#   starts_with_a_to_z: True
#   type: english
#
# Word: application
#   frequency: 1
#   POS: english
#   length: 11
#   lowercase: application
#   starts_with_a_to_z: True
#   type: english
#
# Word: ther
#   frequency: 1
#   POS: english
#   length: 4
#   lowercase: ther
#   starts_with_a_to_z: True
#   type: english
#
# Word: modynamics
#   frequency: 1
#   POS: english
#   length: 10
#   lowercase: modynamics
#   starts_with_a_to_z: True
#   type: english
#
# Word: processes
#   frequency: 1
#   POS: english
#   length: 9
#   lowercase: processes
#   starts_with_a_to_z: True
#   type: english
#
# Word: has
#   frequency: 2
#   POS: english
#   length: 3
#   lowercase: has
#   starts_with_a_to_z: True
#   type: english
#
# Word: been
#   frequency: 1
#   POS: english
#   length: 4
#   lowercase: been
#   starts_with_a_to_z: True
#   type: english
#
# Word: centra
#   frequency: 1
#   POS: english
#   length: 6
#   lowercase: centra
#   starts_with_a_to_z: True
#   type: english
#
# Word: and
#   frequency: 6
#   POS: english
#   length: 3
#   lowercase: and
#   starts_with_a_to_z: True
#   type: english
#
# Word: its
#   frequency: 3
#   POS: english
#   length: 3
#   lowercase: its
#   starts_with_a_to_z: True
#   type: english
#
# Word: english
#   frequency: 2
#   POS: english
#   length: 7
#   lowercase: english
#   starts_with_a_to_z: True
#   type: english
#
# Word: speaking
#   frequency: 2
#   POS: english
#   length: 8
#   lowercase: speaking
#   starts_with_a_to_z: True
#   type: english
#
# Word: sibling
#   frequency: 1
#   POS: english
#   length: 7
#   lowercase: sibling
#   starts_with_a_to_z: True
#   type: english
#
# Word: degrowth
#   frequency: 5
#   POS: english
#   length: 8
#   lowercase: degrowth
#   starts_with_a_to_z: True
#   type: english
#
# Word: central
#   frequency: 1
#   POS: english
#   length: 7
#   lowercase: central
#   starts_with_a_to_z: True
#   type: english
#
# Word: characteristic
#   frequency: 1
#   POS: english
#   length: 14
#   lowercase: characteristic
#   starts_with_a_to_z: True
#   type: english
#
# Word: is
#   frequency: 6
#   POS: english
#   length: 2
#   lowercase: is
#   starts_with_a_to_z: True
#   type: english
#
# Word: critical
#   frequency: 1
#   POS: english
#   length: 8
#   lowercase: critical
#   starts_with_a_to_z: True
#   type: english
#
# Word: stance
#   frequency: 1
#   POS: english
#   length: 6
#   lowercase: stance
#   starts_with_a_to_z: True
#   type: english
#
# Word: towards
#   frequency: 1
#   POS: english
#   length: 7
#   lowercase: towards
#   starts_with_a_to_z: True
#   type: english
#
# Word: human
#   frequency: 2
#   POS: english
#   length: 5
#   lowercase: human
#   starts_with_a_to_z: True
#   type: english
#
# Word: martinez
#   frequency: 2
#   POS: english
#   length: 8
#   lowercase: martinez
#   starts_with_a_to_z: True
#   type: english
#
# Word: alier
#   frequency: 2
#   POS: english
#   length: 5
#   lowercase: alier
#   starts_with_a_to_z: True
#   type: english
#
# Word: et
#   frequency: 7
#   POS: english
#   length: 2
#   lowercase: et
#   starts_with_a_to_z: True
#   type: english
#
# Word: al
#   frequency: 7
#   POS: english
#   length: 2
#   lowercase: al
#   starts_with_a_to_z: True
#   type: english
#
# Word: concretely
#   frequency: 1
#   POS: english
#   length: 10
#   lowercase: concretely
#   starts_with_a_to_z: True
#   type: english
#
# Word: it
#   frequency: 4
#   POS: english
#   length: 2
#   lowercase: it
#   starts_with_a_to_z: True
#   type: english
#
# Word: questions
#   frequency: 3
#   POS: english
#   length: 9
#   lowercase: questions
#   starts_with_a_to_z: True
#   type: english
#
# Word: tacit
#   frequency: 1
#   POS: english
#   length: 5
#   lowercase: tacit
#   starts_with_a_to_z: True
#   type: english
#
# Word: assumption
#   frequency: 1
#   POS: english
#   length: 10
#   lowercase: assumption
#   starts_with_a_to_z: True
#   type: english
#
# Word: that
#   frequency: 5
#   POS: english
#   length: 4
#   lowercase: that
#   starts_with_a_to_z: True
#   type: english
#
# Word: progress
#   frequency: 1
#   POS: english
#   length: 8
#   lowercase: progress
#   starts_with_a_to_z: True
#   type: english
#
# Word: are
#   frequency: 1
#   POS: english
#   length: 3
#   lowercase: are
#   starts_with_a_to_z: True
#   type: english
#
# Word: correlated
#   frequency: 1
#   POS: english
#   length: 10
#   lowercase: correlated
#   starts_with_a_to_z: True
#   type: english
#
# Word: g
#   frequency: 1
#   POS: english
#   length: 1
#   lowercase: g
#   starts_with_a_to_z: True
#   type: english
#
# Word: illich
#   frequency: 1
#   POS: english
#   length: 6
#   lowercase: illich
#   starts_with_a_to_z: True
#   type: english
#
# Word: latouche
#   frequency: 1
#   POS: english
#   length: 8
#   lowercase: latouche
#   starts_with_a_to_z: True
#   type: english
#
# Word: proposes
#   frequency: 1
#   POS: english
#   length: 8
#   lowercase: proposes
#   starts_with_a_to_z: True
#   type: english
#
# Word: voluntary
#   frequency: 1
#   POS: english
#   length: 9
#   lowercase: voluntary
#   starts_with_a_to_z: True
#   type: english
#
# Word: simplicity
#   frequency: 1
#   POS: english
#   length: 10
#   lowercase: simplicity
#   starts_with_a_to_z: True
#   type: english
#
# Word: means
#   frequency: 1
#   POS: english
#   length: 5
#   lowercase: means
#   starts_with_a_to_z: True
#   type: english
#
# Word: tree
#   frequency: 1
#   POS: english
#   length: 4
#   lowercase: tree
#   starts_with_a_to_z: True
#   type: english
#
# Word: individual
#   frequency: 1
#   POS: english
#   length: 10
#   lowercase: individual
#   starts_with_a_to_z: True
#   type: english
#
# Word: from
#   frequency: 2
#   POS: english
#   length: 4
#   lowercase: from
#   starts_with_a_to_z: True
#   type: english
#
# Word: modern
#   frequency: 1
#   POS: english
#   length: 6
#   lowercase: modern
#   starts_with_a_to_z: True
#   type: english
#
# Word: consumerism
#   frequency: 1
#   POS: english
#   length: 11
#   lowercase: consumerism
#   starts_with_a_to_z: True
#   type: english
#
# Word: with
#   frequency: 1
#   POS: english
#   length: 4
#   lowercase: with
#   starts_with_a_to_z: True
#   type: english
#
# Word: places
#   frequency: 1
#   POS: english
#   length: 6
#   lowercase: places
#   starts_with_a_to_z: True
#   type: english
#
# Word: like
#   frequency: 1
#   POS: english
#   length: 4
#   lowercase: like
#   starts_with_a_to_z: True
#   type: english
#
# Word: can
#   frequency: 3
#   POS: english
#   length: 3
#   lowercase: can
#   starts_with_a_to_z: True
#   type: english
#
# Word: decreix
#   frequency: 1
#   POS: english
#   length: 7
#   lowercase: decreix
#   starts_with_a_to_z: True
#   type: english
#
# Word: at
#   frequency: 3
#   POS: english
#   length: 2
#   lowercase: at
#   starts_with_a_to_z: True
#   type: english
#
# Word: spanish
#   frequency: 1
#   POS: english
#   length: 7
#   lowercase: spanish
#   starts_with_a_to_z: True
#   type: english
#
# Word: border
#   frequency: 1
#   POS: english
#   length: 6
#   lowercase: border
#   starts_with_a_to_z: True
#   type: english
#
# Word: exemplified
#   frequency: 1
#   POS: english
#   length: 11
#   lowercase: exemplified
#   starts_with_a_to_z: True
#   type: english
#
# Word: modes
#   frequency: 1
#   POS: english
#   length: 5
#   lowercase: modes
#   starts_with_a_to_z: True
#   type: english
#
# Word: living
#   frequency: 1
#   POS: english
#   length: 6
#   lowercase: living
#   starts_with_a_to_z: True
#   type: english
#
# Word: see
#   frequency: 1
#   POS: english
#   length: 3
#   lowercase: see
#   starts_with_a_to_z: True
#   type: english
#
# Word: http
#   frequency: 1
#   POS: english
#   length: 4
#   lowercase: http
#   starts_with_a_to_z: True
#   type: english
#
# Word: www
#   frequency: 1
#   POS: english
#   length: 3
#   lowercase: www
#   starts_with_a_to_z: True
#   type: english
#
# Word: candecreix
#   frequency: 1
#   POS: english
#   length: 10
#   lowercase: candecreix
#   starts_with_a_to_z: True
#   type: english
#
# Word: cat
#   frequency: 1
#   POS: english
#   length: 3
#   lowercase: cat
#   starts_with_a_to_z: True
#   type: english
#
# Word: historically
#   frequency: 1
#   POS: english
#   length: 12
#   lowercase: historically
#   starts_with_a_to_z: True
#   type: english
#
# Word: discourse
#   frequency: 2
#   POS: english
#   length: 9
#   lowercase: discourse
#   starts_with_a_to_z: True
#   type: english
#
# Word: about
#   frequency: 2
#   POS: english
#   length: 5
#   lowercase: about
#   starts_with_a_to_z: True
#   type: english
#
# Word: older
#   frequency: 1
#   POS: english
#   length: 5
#   lowercase: older
#   starts_with_a_to_z: True
#   type: english
#
# Word: than
#   frequency: 3
#   POS: english
#   length: 4
#   lowercase: than
#   starts_with_a_to_z: True
#   type: english
#
# Word: one
#   frequency: 1
#   POS: english
#   length: 3
#   lowercase: one
#   starts_with_a_to_z: True
#   type: english
#
# Word: but
#   frequency: 2
#   POS: english
#   length: 3
#   lowercase: but
#   starts_with_a_to_z: True
#   type: english
#
# Word: word
#   frequency: 1
#   POS: english
#   length: 4
#   lowercase: word
#   starts_with_a_to_z: True
#   type: english
#
# Word: often
#   frequency: 1
#   POS: english
#   length: 5
#   lowercase: often
#   starts_with_a_to_z: True
#   type: english
#
# Word: translated
#   frequency: 1
#   POS: english
#   length: 10
#   lowercase: translated
#   starts_with_a_to_z: True
#   type: english
#
# Word: texts
#   frequency: 1
#   POS: english
#   length: 5
#   lowercase: texts
#   starts_with_a_to_z: True
#   type: english
#
# Word: martin’s
#   frequency: 1
#   POS: unknown
#   length: 8
#   lowercase: martin’s
#   starts_with_a_to_z: True
#   type: english
#
# Word: making
#   frequency: 1
#   POS: english
#   length: 6
#   lowercase: making
#   starts_with_a_to_z: True
#   type: english
#
# Word: de
#   frequency: 1
#   POS: english
#   length: 2
#   lowercase: de
#   starts_with_a_to_z: True
#   type: english
#
# Word: facto
#   frequency: 1
#   POS: english
#   length: 5
#   lowercase: facto
#   starts_with_a_to_z: True
#   type: english
#
# Word: synonym
#   frequency: 1
#   POS: english
#   length: 7
#   lowercase: synonym
#   starts_with_a_to_z: True
#   type: english
#
# Word: without
#   frequency: 1
#   POS: english
#   length: 7
#   lowercase: without
#   starts_with_a_to_z: True
#   type: english
#
# Word: actually
#   frequency: 1
#   POS: english
#   length: 8
#   lowercase: actually
#   starts_with_a_to_z: True
#   type: english
#
# Word: my
#   frequency: 1
#   POS: english
#   length: 2
#   lowercase: my
#   starts_with_a_to_z: True
#   type: english
#
# Word: name
#   frequency: 1
#   POS: english
#   length: 4
#   lowercase: name
#   starts_with_a_to_z: True
#   type: english
#
# Word: exact
#   frequency: 1
#   POS: english
#   length: 5
#   lowercase: exact
#   starts_with_a_to_z: True
#   type: english
#
# Word: same
#   frequency: 1
#   POS: english
#   length: 4
#   lowercase: same
#   starts_with_a_to_z: True
#   type: english
#
# Word: thing
#   frequency: 1
#   POS: english
#   length: 5
#   lowercase: thing
#   starts_with_a_to_z: True
#   type: english
#
# Word: comparison
#   frequency: 1
#   POS: english
#   length: 10
#   lowercase: comparison
#   starts_with_a_to_z: True
#   type: english
#
# Word: less
#   frequency: 1
#   POS: english
#   length: 4
#   lowercase: less
#   starts_with_a_to_z: True
#   type: english
#
# Word: radical
#   frequency: 1
#   POS: english
#   length: 7
#   lowercase: radical
#   starts_with_a_to_z: True
#   type: english
#
# Word: rooted
#   frequency: 1
#   POS: english
#   length: 6
#   lowercase: rooted
#   starts_with_a_to_z: True
#   type: english
#
# Word: ecological
#   frequency: 3
#   POS: english
#   length: 10
#   lowercase: ecological
#   starts_with_a_to_z: True
#   type: english
#
# Word: economics
#   frequency: 5
#   POS: english
#   length: 9
#   lowercase: economics
#   starts_with_a_to_z: True
#   type: english
#
# Word: criticizes
#   frequency: 1
#   POS: english
#   length: 10
#   lowercase: criticizes
#   starts_with_a_to_z: True
#   type: english
#
# Word: mainstream
#   frequency: 1
#   POS: english
#   length: 10
#   lowercase: mainstream
#   starts_with_a_to_z: True
#   type: english
#
# Word: for
#   frequency: 1
#   POS: english
#   length: 3
#   lowercase: for
#   starts_with_a_to_z: True
#   type: english
#
# Word: example
#   frequency: 1
#   POS: english
#   length: 7
#   lowercase: example
#   starts_with_a_to_z: True
#   type: english
#
# Word: use
#   frequency: 1
#   POS: english
#   length: 3
#   lowercase: use
#   starts_with_a_to_z: True
#   type: english
#
# Word: gdp
#   frequency: 1
#   POS: english
#   length: 3
#   lowercase: gdp
#   starts_with_a_to_z: True
#   type: english
#
# Word: policy
#   frequency: 2
#   POS: english
#   length: 6
#   lowercase: policy
#   starts_with_a_to_z: True
#   type: english
#
# Word: indicator
#   frequency: 1
#   POS: english
#   length: 9
#   lowercase: indicator
#   starts_with_a_to_z: True
#   type: english
#
# Word: seeks
#   frequency: 1
#   POS: english
#   length: 5
#   lowercase: seeks
#   starts_with_a_to_z: True
#   type: english
#
# Word: be
#   frequency: 4
#   POS: english
#   length: 2
#   lowercase: be
#   starts_with_a_to_z: True
#   type: english
#
# Word: vindicate
#   frequency: 1
#   POS: english
#   length: 9
#   lowercase: vindicate
#   starts_with_a_to_z: True
#   type: english
#
# Word: discipline
#   frequency: 2
#   POS: english
#   length: 10
#   lowercase: discipline
#   starts_with_a_to_z: True
#   type: english
#
# Word: aban
#   frequency: 1
#   POS: english
#   length: 4
#   lowercase: aban
#   starts_with_a_to_z: True
#   type: english
#
# Word: doing
#   frequency: 1
#   POS: english
#   length: 5
#   lowercase: doing
#   starts_with_a_to_z: True
#   type: english
#
# Word: adding
#   frequency: 1
#   POS: english
#   length: 6
#   lowercase: adding
#   starts_with_a_to_z: True
#   type: english
#
# Word: body
#   frequency: 1
#   POS: english
#   length: 4
#   lowercase: body
#   starts_with_a_to_z: True
#   type: english
#
# Word: theory
#   frequency: 1
#   POS: english
#   length: 6
#   lowercase: theory
#   starts_with_a_to_z: True
#   type: english
#
# Word: which
#   frequency: 2
#   POS: english
#   length: 5
#   lowercase: which
#   starts_with_a_to_z: True
#   type: english
#
# Word: concrete
#   frequency: 1
#   POS: english
#   length: 8
#   lowercase: concrete
#   starts_with_a_to_z: True
#   type: english
#
# Word: proposals
#   frequency: 1
#   POS: english
#   length: 9
#   lowercase: proposals
#   starts_with_a_to_z: True
#   type: english
#
# Word: developed
#   frequency: 1
#   POS: english
#   length: 9
#   lowercase: developed
#   starts_with_a_to_z: True
#   type: english
#
# Word: thus
#   frequency: 1
#   POS: english
#   length: 4
#   lowercase: thus
#   starts_with_a_to_z: True
#   type: english
#
# Word: aims
#   frequency: 1
#   POS: english
#   length: 4
#   lowercase: aims
#   starts_with_a_to_z: True
#   type: english
#
# Word: reforms
#   frequency: 1
#   POS: english
#   length: 7
#   lowercase: reforms
#   starts_with_a_to_z: True
#   type: english
#
# Word: existing
#   frequency: 1
#   POS: english
#   length: 8
#   lowercase: existing
#   starts_with_a_to_z: True
#   type: english
#
# Word: institutions
#   frequency: 1
#   POS: english
#   length: 12
#   lowercase: institutions
#   starts_with_a_to_z: True
#   type: english
#
# Word: systems
#   frequency: 1
#   POS: english
#   length: 7
#   lowercase: systems
#   starts_with_a_to_z: True
#   type: english
#
# Word: revolutions
#   frequency: 1
#   POS: english
#   length: 11
#   lowercase: revolutions
#   starts_with_a_to_z: True
#   type: english
#
# Word: kalls
#   frequency: 1
#   POS: english
#   length: 5
#   lowercase: kalls
#   starts_with_a_to_z: True
#   type: english
#
# Word: generally
#   frequency: 1
#   POS: english
#   length: 9
#   lowercase: generally
#   starts_with_a_to_z: True
#   type: english
#
# Word: we
#   frequency: 2
#   POS: english
#   length: 2
#   lowercase: we
#   starts_with_a_to_z: True
#   type: english
#
# Word: follow
#   frequency: 1
#   POS: english
#   length: 6
#   lowercase: follow
#   starts_with_a_to_z: True
#   type: english
#
# Word: research
#   frequency: 2
#   POS: english
#   length: 8
#   lowercase: research
#   starts_with_a_to_z: True
#   type: english
#
# Word: design
#   frequency: 1
#   POS: english
#   length: 6
#   lowercase: design
#   starts_with_a_to_z: True
#   type: english
#
# Word: methodology
#   frequency: 1
#   POS: english
#   length: 11
#   lowercase: methodology
#   starts_with_a_to_z: True
#   type: english
#
# Word: listed
#   frequency: 1
#   POS: english
#   length: 6
#   lowercase: listed
#   starts_with_a_to_z: True
#   type: english
#
# Word: our
#   frequency: 1
#   POS: english
#   length: 3
#   lowercase: our
#   starts_with_a_to_z: True
#   type: english
#
# Word: earlier
#   frequency: 1
#   POS: english
#   length: 7
#   lowercase: earlier
#   starts_with_a_to_z: True
#   type: english
#
# Word: systematic
#   frequency: 1
#   POS: english
#   length: 10
#   lowercase: systematic
#   starts_with_a_to_z: True
#   type: english
#
# Word: reviews
#   frequency: 1
#   POS: english
#   length: 7
#   lowercase: reviews
#   starts_with_a_to_z: True
#   type: english
#
# Word: aimed
#   frequency: 1
#   POS: english
#   length: 5
#   lowercase: aimed
#   starts_with_a_to_z: True
#   type: english
#
# Word: concepts
#   frequency: 1
#   POS: english
#   length: 8
#   lowercase: concepts
#   starts_with_a_to_z: True
#   type: english
#
# Word: abson
#   frequency: 1
#   POS: english
#   length: 5
#   lowercase: abson
#   starts_with_a_to_z: True
#   type: english
#
# Word: brandt
#   frequency: 1
#   POS: english
#   length: 6
#   lowercase: brandt
#   starts_with_a_to_z: True
#   type: english
#
# Word: or
#   frequency: 1
#   POS: english
#   length: 2
#   lowercase: or
#   starts_with_a_to_z: True
#   type: english
#
# Word: fields
#   frequency: 1
#   POS: english
#   length: 6
#   lowercase: fields
#   starts_with_a_to_z: True
#   type: english
#
# Word: drupp
#   frequency: 1
#   POS: english
#   length: 5
#   lowercase: drupp
#   starts_with_a_to_z: True
#   type: english
#
# Word: outlining
#   frequency: 1
#   POS: english
#   length: 9
#   lowercase: outlining
#   starts_with_a_to_z: True
#   type: english
#
# Word: this
#   frequency: 1
#   POS: english
#   length: 4
#   lowercase: this
#   starts_with_a_to_z: True
#   type: english
#
# Word: process
#   frequency: 1
#   POS: english
#   length: 7
#   lowercase: process
#   starts_with_a_to_z: True
#   type: english
#
# Word: following
#   frequency: 1
#   POS: english
#   length: 9
#   lowercase: following
#   starts_with_a_to_z: True
#   type: english
#
# Word: graphical
#   frequency: 1
#   POS: english
#   length: 9
#   lowercase: graphical
#   starts_with_a_to_z: True
#   type: english
#
# Word: overview
#   frequency: 1
#   POS: english
#   length: 8
#   lowercase: overview
#   starts_with_a_to_z: True
#   type: english
#
# Word: found
#   frequency: 1
#   POS: english
#   length: 5
#   lowercase: found
#   starts_with_a_to_z: True
#   type: english
#
# Word: fig
#   frequency: 1
#   POS: english
#   length: 3
#   lowercase: fig
#   starts_with_a_to_z: True
#   type: english
#
# Word: allier
#   frequency: 1
#   POS: english
#   length: 6
#   lowercase: allier
#   starts_with_a_to_z: True
#   type: english
#
# Word: clear
#   frequency: 1
#   POS: english
#   length: 5
#   lowercase: clear
#   starts_with_a_to_z: True
#   type: english
#
# Word: eco
#   frequency: 1
#   POS: english
#   length: 3
#   lowercase: eco
#   starts_with_a_to_z: True
#   type: english
#
# Word: socialist
#   frequency: 1
#   POS: english
#   length: 9
#   lowercase: socialist
#   starts_with_a_to_z: True
#   type: english
#
# Word: agenda
#   frequency: 1
#   POS: english
#   length: 6
#   lowercase: agenda
#   starts_with_a_to_z: True
#   type: english
#
# Word: sees
#   frequency: 1
#   POS: english
#   length: 4
#   lowercase: sees
#   starts_with_a_to_z: True
#   type: english
#
# Word: necessarily
#   frequency: 1
#   POS: english
#   length: 11
#   lowercase: necessarily
#   starts_with_a_to_z: True
#   type: english
#
# Word: political
#   frequency: 1
#   POS: english
#   length: 9
#   lowercase: political
#   starts_with_a_to_z: True
#   type: english
#
# Word: ultimately
#   frequency: 1
#   POS: english
#   length: 10
#   lowercase: ultimately
#   starts_with_a_to_z: True
#   type: english
#
# Word: lead
#   frequency: 1
#   POS: english
#   length: 4
#   lowercase: lead
#   starts_with_a_to_z: True
#   type: english
#
# Word: abolishment
#   frequency: 1
#   POS: english
#   length: 11
#   lowercase: abolishment
#   starts_with_a_to_z: True
#   type: english
#
# Word: capitalism
#   frequency: 1
#   POS: english
#   length: 10
#   lowercase: capitalism
#   starts_with_a_to_z: True
#   type: english
#
# Word: furthermore
#   frequency: 1
#   POS: english
#   length: 11
#   lowercase: furthermore
#   starts_with_a_to_z: True
#   type: english
#
# Word: anti
#   frequency: 1
#   POS: english
#   length: 4
#   lowercase: anti
#   starts_with_a_to_z: True
#   type: english
#
# Word: sense
#   frequency: 1
#   POS: english
#   length: 5
#   lowercase: sense
#   starts_with_a_to_z: True
#   type: english
#
# Word: seen
#   frequency: 1
#   POS: english
#   length: 4
#   lowercase: seen
#   starts_with_a_to_z: True
#   type: english
#
# Word: should
#   frequency: 1
#   POS: english
#   length: 6
#   lowercase: should
#   starts_with_a_to_z: True
#   type: english
#
# Word: abandoned
#   frequency: 1
#   POS: english
#   length: 9
#   lowercase: abandoned
#   starts_with_a_to_z: True
#   type: english
#
# Word: ibid
#   frequency: 1
#   POS: english
#   length: 4
#   lowercase: ibid
#   starts_with_a_to_z: True
#   type: english
